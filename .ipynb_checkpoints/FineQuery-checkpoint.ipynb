# %%
import pandas as pd
import sqlalchemy as db
import os

# %%
conn = pd.read_json('connection.json', typ='series')
host = conn['host']
user = conn['user']
password = conn['password']
port = conn['port']

db_name = input('DB Name: ')
engine = db.create_engine('mysql+pymysql://' + user + ':' + password + '@' + host + ':' + port + '/' + db_name)
# Out:
# DB Name: PALB777

# %%
limit = 100_000
offset = 0
plane = 'rp7778'
year = 2022
df = []

while True:
    try:
        data = pd.read_sql(f"SELECT * FROM `{plane}-{year}` LIMIT {limit} OFFSET {offset}", engine)
        planeIDs = list(data['ID'].unique())
        dates = list(data['Date'].unique())
        minIndex = min(data['index'])
        maxIndex = max(data['index'])
        rm = list(data['RM'].unique())
        acft = list(data['Plane'].unique())
        data.to_parquet(f"{db_name}/{plane}-{year}/{offset}_{offset + limit}.parquet")
        print(f"ID: {planeIDs}, Dates: {dates}, IndexRange: ({minIndex, maxIndex})")
        print(f"Aircraft Included: {acft}, Registration Marking: {rm}")
        print(f"Index Counter: {offset} - {offset + limit}")
        print("-------------------------------------------------------------------")
        offset += limit
    except Exception as e:
        print(f"AN ERROR OCCURED: {e}")
        break
# Out:
# ID: [6, 14, 26], Dates: ['2022-01-02', '2022-01-03', '2022-01-05'], IndexRange: ((0, 55847))
# Aircraft Included: ['PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 0 - 100000
# -------------------------------------------------------------------
# ID: [26, 37, 43], Dates: ['2022-01-05', '2022-01-06'], IndexRange: ((0, 54383))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL8539'], Registration Marking: ['RP7778']
# Index Counter: 100000 - 200000
# -------------------------------------------------------------------
# ID: [43, 46, 51, 55], Dates: ['2022-01-06', '2022-01-07', '2022-01-08'], IndexRange: ((0, 40163))
# Aircraft Included: ['PAL8539', 'PAL104', 'PAL8540', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 200000 - 300000
# -------------------------------------------------------------------
# ID: [55, 59, 67], Dates: ['2022-01-08', '2022-01-09', '2022-01-10'], IndexRange: ((0, 53467))
# Aircraft Included: ['PAL105', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 300000 - 400000
# -------------------------------------------------------------------
# ID: [67, 74, 82], Dates: ['2022-01-10', '2022-01-11', '2022-01-12'], IndexRange: ((0, 54199))
# Aircraft Included: ['PAL103', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 400000 - 500000
# -------------------------------------------------------------------
# ID: [82, 86, 92, 93, 99], Dates: ['2022-01-12', '2022-01-13', '2022-01-14'], IndexRange: ((0, 55339))
# Aircraft Included: ['PAL103', 'PAL382', 'PAL383', 'PAL8118', 'PAL8119'], Registration Marking: ['RP7778']
# Index Counter: 500000 - 600000
# -------------------------------------------------------------------
# ID: [99, 103, 111], Dates: ['2022-01-14', '2022-01-15', '2022-01-16'], IndexRange: ((0, 63411))
# Aircraft Included: ['PAL8119', 'PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 600000 - 700000
# -------------------------------------------------------------------
# ID: [111, 112, 113, 117, 121], Dates: ['2022-01-16', '2022-01-17', '2022-01-18'], IndexRange: ((0, 50079))
# Aircraft Included: ['PAL117', 'PAL382', 'PAL102', 'PAL383', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 700000 - 800000
# -------------------------------------------------------------------
# ID: [121, 126, 129], Dates: ['2022-01-18', '2022-01-19'], IndexRange: ((0, 56139))
# Aircraft Included: ['PAL103', 'PAL8539', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 800000 - 900000
# -------------------------------------------------------------------
# ID: [129, 134, 137, 148], Dates: ['2022-01-19', '2022-01-20', '2022-01-22'], IndexRange: ((0, 53739))
# Aircraft Included: ['PAL104', 'PAL8540', 'PAL105', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 900000 - 1000000
# -------------------------------------------------------------------
# ID: [148, 153, 156, 160], Dates: ['2022-01-22', '2022-01-23', '2022-01-24'], IndexRange: ((0, 54655))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL382'], Registration Marking: ['RP7778']
# Index Counter: 1000000 - 1100000
# -------------------------------------------------------------------
# ID: [160, 167, 170, 173], Dates: ['2022-01-24', '2022-01-25'], IndexRange: ((0, 54595))
# Aircraft Included: ['PAL102', 'PAL383', 'PAL103', 'PAL8539'], Registration Marking: ['RP7778']
# Index Counter: 1100000 - 1200000
# -------------------------------------------------------------------
# ID: [173, 181, 182, 189], Dates: ['2022-01-25', '2022-01-26', '2022-01-27', '2022-01-28'], IndexRange: ((0, 44439))
# Aircraft Included: ['PAL8539', 'PAL8540', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 1200000 - 1300000
# -------------------------------------------------------------------
# ID: [189, 195, 197, 200, 204], Dates: ['2022-01-28', '2022-01-29', '2022-01-30'], IndexRange: ((0, 54439))
# Aircraft Included: ['PAL103', 'PAL591', 'PAL102', 'PAL592'], Registration Marking: ['RP7778']
# Index Counter: 1300000 - 1400000
# -------------------------------------------------------------------
# ID: [204, 215, 217], Dates: ['2022-01-30', '2022-01-31'], IndexRange: ((0, 54607))
# Aircraft Included: ['PAL103', 'PAL113', 'PAL5112'], Registration Marking: ['RP7778']
# Index Counter: 1400000 - 1500000
# -------------------------------------------------------------------
# ID: [217, 220, 227], Dates: ['2022-01-31', '2022-02-01', '2022-02-02'], IndexRange: ((0, 43499))
# Aircraft Included: ['PAL5112', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 1500000 - 1600000
# -------------------------------------------------------------------
# ID: [227, 232, 240], Dates: ['2022-02-02', '2022-02-03', '2022-02-04'], IndexRange: ((0, 51183))
# Aircraft Included: ['PAL105', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 1600000 - 1700000
# -------------------------------------------------------------------
# ID: [240, 246, 252], Dates: ['2022-02-04', '2022-02-05', '2022-02-06'], IndexRange: ((0, 54823))
# Aircraft Included: ['PAL105', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 1700000 - 1800000
# -------------------------------------------------------------------
# ID: [252, 269, 276], Dates: ['2022-02-06', '2022-02-08', '2022-02-09'], IndexRange: ((0, 51715))
# Aircraft Included: ['PAL105', 'PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 1800000 - 1900000
# -------------------------------------------------------------------
# ID: [276, 280, 284, 287, 290], Dates: ['2022-02-09', '2022-02-10', '2022-02-11'], IndexRange: ((0, 50215))
# Aircraft Included: ['PAL117', 'PAL591', 'PAL116', 'PAL592'], Registration Marking: ['RP7778']
# Index Counter: 1900000 - 2000000
# -------------------------------------------------------------------
# ID: [290, 295, 296], Dates: ['2022-02-11', '2022-02-12'], IndexRange: ((0, 48387))
# Aircraft Included: ['PAL117', 'PAL5116', 'PAL5117'], Registration Marking: ['RP7778']
# Index Counter: 2000000 - 2100000
# -------------------------------------------------------------------
# ID: [296, 297, 301], Dates: ['2022-02-12', '2022-02-13', '2022-02-14'], IndexRange: ((0, 50407))
# Aircraft Included: ['PAL5117', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 2100000 - 2200000
# -------------------------------------------------------------------
# ID: [301, 307, 308, 309, 314], Dates: ['2022-02-14', '2022-02-15', '2022-02-16'], IndexRange: ((0, 53947))
# Aircraft Included: ['PAL103', 'PAL116', 'PAL591', 'PAL592', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 2200000 - 2300000
# -------------------------------------------------------------------
# ID: [314, 316, 317, 321, 322], Dates: ['2022-02-16', '2022-02-17', '2022-02-18'], IndexRange: ((0, 50151))
# Aircraft Included: ['PAL117', 'PAL591', 'PAL102', 'PAL592', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 2300000 - 2400000
# -------------------------------------------------------------------
# ID: [322, 328, 334], Dates: ['2022-02-18', '2022-02-19', '2022-02-20'], IndexRange: ((0, 55163))
# Aircraft Included: ['PAL103', 'PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 2400000 - 2500000
# -------------------------------------------------------------------
# ID: [334, 341, 342], Dates: ['2022-02-20', '2022-02-21'], IndexRange: ((0, 53171))
# Aircraft Included: ['PAL117', 'PAL113', 'PAL5112'], Registration Marking: ['RP7778']
# Index Counter: 2500000 - 2600000
# -------------------------------------------------------------------
# ID: [342, 344, 352], Dates: ['2022-02-21', '2022-02-22', '2022-02-23'], IndexRange: ((0, 45123))
# Aircraft Included: ['PAL5112', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 2600000 - 2700000
# -------------------------------------------------------------------
# ID: [352, 358, 367], Dates: ['2022-02-23', '2022-02-24', '2022-02-25'], IndexRange: ((0, 54163))
# Aircraft Included: ['PAL103', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 2700000 - 2800000
# -------------------------------------------------------------------
# ID: [367, 376, 385], Dates: ['2022-02-25', '2022-02-26', '2022-02-27'], IndexRange: ((0, 54223))
# Aircraft Included: ['PAL103', 'PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 2800000 - 2900000
# -------------------------------------------------------------------
# ID: [385, 389, 396], Dates: ['2022-02-27', '2022-02-28', '2022-03-01'], IndexRange: ((0, 51551))
# Aircraft Included: ['PAL117', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 2900000 - 3000000
# -------------------------------------------------------------------
# ID: [396, 402, 409], Dates: ['2022-03-01', '2022-03-02', '2022-03-03'], IndexRange: ((0, 53543))
# Aircraft Included: ['PAL105', 'PAL118', 'PAL119'], Registration Marking: ['RP7778']
# Index Counter: 3000000 - 3100000
# -------------------------------------------------------------------
# ID: [409, 414, 416], Dates: ['2022-03-03', '2022-03-04'], IndexRange: ((0, 60623))
# Aircraft Included: ['PAL119', 'PAL112', 'PAL153'], Registration Marking: ['RP7778']
# Index Counter: 3100000 - 3200000
# -------------------------------------------------------------------
# ID: [416, 418, 421, 424], Dates: ['2022-03-04', '2022-03-05', '2022-03-06'], IndexRange: ((0, 55523))
# Aircraft Included: ['PAL153', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 3200000 - 3300000
# -------------------------------------------------------------------
# ID: [424, 429, 437], Dates: ['2022-03-06', '2022-03-07', '2022-03-08'], IndexRange: ((0, 53327))
# Aircraft Included: ['PAL105', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 3300000 - 3400000
# -------------------------------------------------------------------
# ID: [437, 444, 453], Dates: ['2022-03-08', '2022-03-09', '2022-03-10'], IndexRange: ((0, 53811))
# Aircraft Included: ['PAL103', 'PAL118', 'PAL119'], Registration Marking: ['RP7778']
# Index Counter: 3400000 - 3500000
# -------------------------------------------------------------------
# ID: [453, 460, 462], Dates: ['2022-03-10', '2022-03-11'], IndexRange: ((0, 58759))
# Aircraft Included: ['PAL119', 'PAL112', 'PAL153'], Registration Marking: ['RP7778']
# Index Counter: 3500000 - 3600000
# -------------------------------------------------------------------
# ID: [462, 468, 469, 476], Dates: ['2022-03-11', '2022-03-12', '2022-03-13', '2022-03-14'], IndexRange: ((0, 54831))
# Aircraft Included: ['PAL153', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 3600000 - 3700000
# -------------------------------------------------------------------
# ID: [476, 484, 487], Dates: ['2022-03-14', '2022-03-15', '2022-03-16'], IndexRange: ((0, 54147))
# Aircraft Included: ['PAL103', 'PAL5112', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 3700000 - 3800000
# -------------------------------------------------------------------
# ID: [487, 493, 494, 498, 500, 506], Dates: ['2022-03-16', '2022-03-17', '2022-03-18'], IndexRange: ((0, 53299))
# Aircraft Included: ['PAL105', 'PAL5112', 'PAL591', 'PAL116', 'PAL592', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 3800000 - 3900000
# -------------------------------------------------------------------
# ID: [506, 507, 511, 514], Dates: ['2022-03-18', '2022-03-19'], IndexRange: ((0, 50931))
# Aircraft Included: ['PAL117', 'PAL591', 'PAL104', 'PAL592'], Registration Marking: ['RP7778']
# Index Counter: 3900000 - 4000000
# -------------------------------------------------------------------
# ID: [514, 517, 524], Dates: ['2022-03-19', '2022-03-20', '2022-03-21'], IndexRange: ((0, 53847))
# Aircraft Included: ['PAL592', 'PAL105', 'PAL112'], Registration Marking: ['RP7778']
# Index Counter: 4000000 - 4100000
# -------------------------------------------------------------------
# ID: [524, 525, 530], Dates: ['2022-03-21', '2022-03-22'], IndexRange: ((0, 54531))
# Aircraft Included: ['PAL112', 'PAL113', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 4100000 - 4200000
# -------------------------------------------------------------------
# ID: [530, 535, 542, 543], Dates: ['2022-03-22', '2022-03-23', '2022-03-24'], IndexRange: ((0, 52695))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL591'], Registration Marking: ['RP7778']
# Index Counter: 4200000 - 4300000
# -------------------------------------------------------------------
# ID: [543, 552, 554, 559], Dates: ['2022-03-24', '2022-03-25', '2022-03-26'], IndexRange: ((0, 53295))
# Aircraft Included: ['PAL102', 'PAL592', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 4300000 - 4400000
# -------------------------------------------------------------------
# ID: [559, 567, 574], Dates: ['2022-03-26', '2022-03-27', '2022-03-28'], IndexRange: ((0, 52491))
# Aircraft Included: ['PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 4400000 - 4500000
# -------------------------------------------------------------------
# ID: [574, 581, 592], Dates: ['2022-03-28', '2022-03-29', '2022-03-30'], IndexRange: ((0, 52787))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL118'], Registration Marking: ['RP7778']
# Index Counter: 4500000 - 4600000
# -------------------------------------------------------------------
# ID: [592, 600, 601, 607], Dates: ['2022-03-30', '2022-03-31', '2022-04-01'], IndexRange: ((0, 54035))
# Aircraft Included: ['PAL118', 'PAL119', 'PAL112'], Registration Marking: ['RP7778']
# Index Counter: 4600000 - 4700000
# -------------------------------------------------------------------
# ID: [607, 608, 615], Dates: ['2022-04-01', '2022-04-02'], IndexRange: ((0, 54055))
# Aircraft Included: ['PAL112', 'PAL113', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 4700000 - 4800000
# -------------------------------------------------------------------
# ID: [615, 626, 637], Dates: ['2022-04-02', '2022-04-03', '2022-04-04'], IndexRange: ((0, 51571))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL112'], Registration Marking: ['RP7778']
# Index Counter: 4800000 - 4900000
# -------------------------------------------------------------------
# ID: [637, 638, 651], Dates: ['2022-04-04', '2022-04-06'], IndexRange: ((0, 53895))
# Aircraft Included: ['PAL112', 'PAL113', 'PAL118'], Registration Marking: ['RP7778']
# Index Counter: 4900000 - 5000000
# -------------------------------------------------------------------
# ID: [651, 660, 661], Dates: ['2022-04-06', '2022-04-07'], IndexRange: ((0, 54107))
# Aircraft Included: ['PAL118', 'PAL119'], Registration Marking: ['RP7778']
# Index Counter: 5000000 - 5100000
# -------------------------------------------------------------------
# ID: [661, 665, 675], Dates: ['2022-04-07', '2022-04-08', '2022-04-09'], IndexRange: ((0, 53995))
# Aircraft Included: ['PAL119', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 5100000 - 5200000
# -------------------------------------------------------------------
# ID: [675, 682, 683], Dates: ['2022-04-09', '2022-04-10'], IndexRange: ((0, 54051))
# Aircraft Included: ['PAL105', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 5200000 - 5300000
# -------------------------------------------------------------------
# ID: [683, 686, 695], Dates: ['2022-04-10', '2022-04-11', '2022-04-12'], IndexRange: ((0, 55147))
# Aircraft Included: ['PAL113', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 5300000 - 5400000
# -------------------------------------------------------------------
# ID: [695, 710, 719, 723], Dates: ['2022-04-12', '2022-04-14', '2022-04-15'], IndexRange: ((0, 54543))
# Aircraft Included: ['PAL103', 'PAL116', 'PAL117', 'PAL591'], Registration Marking: ['RP7778']
# Index Counter: 5400000 - 5500000
# -------------------------------------------------------------------
# ID: [723, 724, 730, 732], Dates: ['2022-04-15', '2022-04-16', '2022-04-17'], IndexRange: ((0, 44835))
# Aircraft Included: ['PAL591', 'PAL102', 'PAL592', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 5500000 - 5600000
# -------------------------------------------------------------------
# ID: [732, 744, 745], Dates: ['2022-04-17', '2022-04-18'], IndexRange: ((0, 53251))
# Aircraft Included: ['PAL103', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 5600000 - 5700000
# -------------------------------------------------------------------
# ID: [745, 750, 759], Dates: ['2022-04-18', '2022-04-19', '2022-04-20'], IndexRange: ((0, 53655))
# Aircraft Included: ['PAL113', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 5700000 - 5800000
# -------------------------------------------------------------------
# ID: [759, 767, 777, 782], Dates: ['2022-04-20', '2022-04-21', '2022-04-22'], IndexRange: ((0, 52839))
# Aircraft Included: ['PAL105', 'PAL104', 'PAL591'], Registration Marking: ['RP7778']
# Index Counter: 5800000 - 5900000
# -------------------------------------------------------------------
# ID: [782, 788, 790, 798], Dates: ['2022-04-22', '2022-04-23', '2022-04-24'], IndexRange: ((0, 44263))
# Aircraft Included: ['PAL591', 'PAL116', 'PAL592', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 5900000 - 6000000
# -------------------------------------------------------------------
# ID: [798, 804, 805], Dates: ['2022-04-24', '2022-04-25'], IndexRange: ((0, 49123))
# Aircraft Included: ['PAL117', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 6000000 - 6100000
# -------------------------------------------------------------------
# ID: [805, 809, 816], Dates: ['2022-04-25', '2022-04-26', '2022-04-27'], IndexRange: ((0, 52879))
# Aircraft Included: ['PAL113', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 6100000 - 6200000
# -------------------------------------------------------------------
# ID: [816, 823, 829, 834, 842], Dates: ['2022-04-27', '2022-04-28', '2022-04-29'], IndexRange: ((0, 52283))
# Aircraft Included: ['PAL103', 'PAL591', 'PAL116', 'PAL592', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 6200000 - 6300000
# -------------------------------------------------------------------
# ID: [842, 843, 849, 853, 861], Dates: ['2022-04-29', '2022-04-30', '2022-05-01'], IndexRange: ((0, 49235))
# Aircraft Included: ['PAL117', 'PAL591', 'PAL116', 'PAL592'], Registration Marking: ['RP7778']
# Index Counter: 6300000 - 6400000
# -------------------------------------------------------------------
# ID: [861, 866, 867], Dates: ['2022-05-01', '2022-05-02'], IndexRange: ((0, 47623))
# Aircraft Included: ['PAL117', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 6400000 - 6500000
# -------------------------------------------------------------------
# ID: [867, 871, 876], Dates: ['2022-05-02', '2022-05-03', '2022-05-04'], IndexRange: ((0, 49831))
# Aircraft Included: ['PAL113', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 6500000 - 6600000
# -------------------------------------------------------------------
# ID: [876, 883, 894, 899], Dates: ['2022-05-04', '2022-05-05', '2022-05-06'], IndexRange: ((0, 51131))
# Aircraft Included: ['PAL105', 'PAL104', 'PAL591'], Registration Marking: ['RP7778']
# Index Counter: 6600000 - 6700000
# -------------------------------------------------------------------
# ID: [899, 906, 909, 918], Dates: ['2022-05-06', '2022-05-07', '2022-05-08', '2022-05-09'], IndexRange: ((0, 44315))
# Aircraft Included: ['PAL591', 'PAL592', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 6700000 - 6800000
# -------------------------------------------------------------------
# ID: [918, 967, 972], Dates: ['2022-05-09', '2022-05-15', '2022-05-16'], IndexRange: ((0, 52331))
# Aircraft Included: ['PAL105', 'PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 6800000 - 6900000
# -------------------------------------------------------------------
# ID: [972, 976, 985, 992], Dates: ['2022-05-16', '2022-05-17', '2022-05-18', '2022-05-19'], IndexRange: ((0, 50055))
# Aircraft Included: ['PAL117', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 6900000 - 7000000
# -------------------------------------------------------------------
# ID: [992, 1001, 1005], Dates: ['2022-05-19', '2022-05-20'], IndexRange: ((0, 51295))
# Aircraft Included: ['PAL104', 'PAL105', 'PAL591'], Registration Marking: ['RP7778']
# Index Counter: 7000000 - 7100000
# -------------------------------------------------------------------
# ID: [1005, 1010, 1014, 1019], Dates: ['2022-05-20', '2022-05-21', '2022-05-22'], IndexRange: ((0, 45583))
# Aircraft Included: ['PAL591', 'PAL116', 'PAL592', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 7100000 - 7200000
# -------------------------------------------------------------------
# ID: [1019, 1021, 1030, 1037], Dates: ['2022-05-22', '2022-05-23', '2022-05-24', '2022-05-25'], IndexRange: ((0, 51231))
# Aircraft Included: ['PAL117', 'PAL102', 'PAL103', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 7200000 - 7300000
# -------------------------------------------------------------------
# ID: [1037, 1045, 1048], Dates: ['2022-05-25', '2022-05-26'], IndexRange: ((0, 48639))
# Aircraft Included: ['PAL116', 'PAL117', 'PAL428'], Registration Marking: ['RP7778']
# Index Counter: 7300000 - 7400000
# -------------------------------------------------------------------
# ID: [1048, 1052, 1056, 1063], Dates: ['2022-05-26', '2022-05-27', '2022-05-28'], IndexRange: ((0, 42715))
# Aircraft Included: ['PAL428', 'PAL104', 'PAL427', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 7400000 - 7500000
# -------------------------------------------------------------------
# ID: [1063, 1069, 1077], Dates: ['2022-05-28', '2022-05-29', '2022-05-30'], IndexRange: ((0, 50499))
# Aircraft Included: ['PAL105', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 7500000 - 7600000
# -------------------------------------------------------------------
# ID: [1077, 1089, 1090, 1091, 1097], Dates: ['2022-05-30', '2022-05-31', '2022-06-01'], IndexRange: ((0, 51795))
# Aircraft Included: ['PAL103', 'PAL116', 'PAL591', 'PAL592', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 7600000 - 7700000
# -------------------------------------------------------------------
# ID: [1097, 1107, 1108], Dates: ['2022-06-01', '2022-06-02'], IndexRange: ((0, 48363))
# Aircraft Included: ['PAL117', 'PAL5104', 'PAL5105'], Registration Marking: ['RP7778']
# Index Counter: 7700000 - 7800000
# -------------------------------------------------------------------
# ID: [1108, 1113, 1122], Dates: ['2022-06-02', '2022-06-03', '2022-06-04'], IndexRange: ((0, 52327))
# Aircraft Included: ['PAL5105', 'PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 7800000 - 7900000
# -------------------------------------------------------------------
# ID: [1122, 1123, 1130, 1133, 1139], Dates: ['2022-06-04', '2022-06-05', '2022-06-06'], IndexRange: ((0, 45739))
# Aircraft Included: ['PAL117', 'PAL382', 'PAL116', 'PAL383'], Registration Marking: ['RP7778']
# Index Counter: 7900000 - 8000000
# -------------------------------------------------------------------
# ID: [1139, 1151, 1152], Dates: ['2022-06-06', '2022-06-07'], IndexRange: ((0, 47367))
# Aircraft Included: ['PAL117', 'PAL5104', 'PAL5105'], Registration Marking: ['RP7778']
# Index Counter: 8000000 - 8100000
# -------------------------------------------------------------------
# ID: [1152, 1156, 1161, 1166], Dates: ['2022-06-07', '2022-06-08', '2022-06-09', '2022-06-10'], IndexRange: ((0, 52851))
# Aircraft Included: ['PAL5105', 'PAL116', 'PAL117', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 8100000 - 8200000
# -------------------------------------------------------------------
# ID: [1166, 1171, 1172, 1175], Dates: ['2022-06-10', '2022-06-11'], IndexRange: ((0, 41827))
# Aircraft Included: ['PAL104', 'PAL597', 'PAL598', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 8200000 - 8300000
# -------------------------------------------------------------------
# ID: [1175, 1186, 1193, 1194], Dates: ['2022-06-11', '2022-06-12', '2022-06-13'], IndexRange: ((0, 55299))
# Aircraft Included: ['PAL105', 'PAL118', 'PAL119'], Registration Marking: ['RP7778']
# Index Counter: 8300000 - 8400000
# -------------------------------------------------------------------
# ID: [1194, 1214, 1224], Dates: ['2022-06-13', '2022-06-16', '2022-06-17'], IndexRange: ((0, 48795))
# Aircraft Included: ['PAL119', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 8400000 - 8500000
# -------------------------------------------------------------------
# ID: [1224, 1233, 1240], Dates: ['2022-06-17', '2022-06-18', '2022-06-19'], IndexRange: ((0, 49111))
# Aircraft Included: ['PAL105', 'PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 8500000 - 8600000
# -------------------------------------------------------------------
# ID: [1240, 1246, 1259, 1260], Dates: ['2022-06-19', '2022-06-20', '2022-06-21'], IndexRange: ((0, 48779))
# Aircraft Included: ['PAL117', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 8600000 - 8700000
# -------------------------------------------------------------------
# ID: [1260, 1267, 1272], Dates: ['2022-06-21', '2022-06-22', '2022-06-23'], IndexRange: ((0, 49983))
# Aircraft Included: ['PAL105', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 8700000 - 8800000
# -------------------------------------------------------------------
# ID: [1272, 1281, 1282, 1286, 1288, 1289, 1299], Dates: ['2022-06-23', '2022-06-24', '2022-06-25'], IndexRange: ((0, 48559))
# Aircraft Included: ['PAL105', 'PAL382', 'PAL116', 'PAL383', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 8800000 - 8900000
# -------------------------------------------------------------------
# ID: [1299, 1306, 1307], Dates: ['2022-06-25', '2022-06-26'], IndexRange: ((0, 47707))
# Aircraft Included: ['PAL117', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 8900000 - 9000000
# -------------------------------------------------------------------
# ID: [1307, 1314, 1325], Dates: ['2022-06-26', '2022-06-27', '2022-06-28'], IndexRange: ((0, 51043))
# Aircraft Included: ['PAL113', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 9000000 - 9100000
# -------------------------------------------------------------------
# ID: [1325, 1332, 1340, 1341], Dates: ['2022-06-28', '2022-06-29'], IndexRange: ((0, 55651))
# Aircraft Included: ['PAL103', 'PAL453P', 'PAL118', 'PAL454P'], Registration Marking: ['RP7778']
# Index Counter: 9100000 - 9200000
# -------------------------------------------------------------------
# ID: [1341, 1350, 1351, 1361], Dates: ['2022-06-29', '2022-06-30', '2022-07-01'], IndexRange: ((0, 47907))
# Aircraft Included: ['PAL454P', 'PAL119', 'PAL118'], Registration Marking: ['RP7778']
# Index Counter: 9200000 - 9300000
# -------------------------------------------------------------------
# ID: [1361, 1371, 1372, 1380], Dates: ['2022-07-01', '2022-07-02', '2022-07-03'], IndexRange: ((0, 60739))
# Aircraft Included: ['PAL118', 'PAL119', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 9300000 - 9400000
# -------------------------------------------------------------------
# ID: [1380, 1390, 1391, 1399], Dates: ['2022-07-03', '2022-07-04', '2022-07-05'], IndexRange: ((0, 46991))
# Aircraft Included: ['PAL116', 'PAL117', 'PAL112'], Registration Marking: ['RP7778']
# Index Counter: 9400000 - 9500000
# -------------------------------------------------------------------
# ID: [1399, 1400, 1408], Dates: ['2022-07-05', '2022-07-06'], IndexRange: ((0, 50783))
# Aircraft Included: ['PAL112', 'PAL113', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 9500000 - 9600000
# -------------------------------------------------------------------
# ID: [1408, 1417, 1425], Dates: ['2022-07-06', '2022-07-07', '2022-07-08'], IndexRange: ((0, 49863))
# Aircraft Included: ['PAL104', 'PAL105', 'PAL112'], Registration Marking: ['RP7778']
# Index Counter: 9600000 - 9700000
# -------------------------------------------------------------------
# ID: [1425, 1426, 1436], Dates: ['2022-07-08', '2022-07-09'], IndexRange: ((0, 50763))
# Aircraft Included: ['PAL112', 'PAL113', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 9700000 - 9800000
# -------------------------------------------------------------------
# ID: [1436, 1448, 1461], Dates: ['2022-07-09', '2022-07-10', '2022-07-11'], IndexRange: ((0, 49107))
# Aircraft Included: ['PAL116', 'PAL117', 'PAL5104'], Registration Marking: ['RP7778']
# Index Counter: 9800000 - 9900000
# -------------------------------------------------------------------
# ID: [1461, 1462, 1464], Dates: ['2022-07-11', '2022-07-12'], IndexRange: ((0, 49239))
# Aircraft Included: ['PAL5104', 'PAL5105', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 9900000 - 10000000
# -------------------------------------------------------------------
# ID: [1464, 1476, 1483, 1486], Dates: ['2022-07-12', '2022-07-13', '2022-07-14'], IndexRange: ((0, 51211))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL890', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 10000000 - 10100000
# -------------------------------------------------------------------
# ID: [1486, 1494, 1497, 1520], Dates: ['2022-07-14', '2022-07-15', '2022-07-16'], IndexRange: ((0, 48567))
# Aircraft Included: ['PAL104', 'PAL891', 'PAL105', 'PAL5104'], Registration Marking: ['RP7778']
# Index Counter: 10100000 - 10200000
# -------------------------------------------------------------------
# ID: [1520, 1521, 1528], Dates: ['2022-07-16', '2022-07-17'], IndexRange: ((0, 47871))
# Aircraft Included: ['PAL5104', 'PAL5105', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 10200000 - 10300000
# -------------------------------------------------------------------
# ID: [1528, 1538, 1543], Dates: ['2022-07-17', '2022-07-18', '2022-07-19'], IndexRange: ((0, 47255))
# Aircraft Included: ['PAL116', 'PAL117', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 10300000 - 10400000
# -------------------------------------------------------------------
# ID: [1543, 1555, 1565], Dates: ['2022-07-19', '2022-07-20', '2022-07-21'], IndexRange: ((0, 47995))
# Aircraft Included: ['PAL104', 'PAL105', 'PAL112'], Registration Marking: ['RP7778']
# Index Counter: 10400000 - 10500000
# -------------------------------------------------------------------
# ID: [1565, 1566, 1570], Dates: ['2022-07-21', '2022-07-22'], IndexRange: ((0, 50079))
# Aircraft Included: ['PAL112', 'PAL113', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 10500000 - 10600000
# -------------------------------------------------------------------
# ID: [1570, 1581, 1582, 1583, 1595], Dates: ['2022-07-22', '2022-07-23', '2022-07-24'], IndexRange: ((0, 49411))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 10600000 - 10700000
# -------------------------------------------------------------------
# ID: [1595, 1603, 1604, 1608, 1616], Dates: ['2022-07-24', '2022-07-25', '2022-07-26'], IndexRange: ((0, 48343))
# Aircraft Included: ['PAL104', 'PAL382', 'PAL383', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 10700000 - 10800000
# -------------------------------------------------------------------
# ID: [1616, 1627, 1633, 1634], Dates: ['2022-07-26', '2022-07-27', '2022-07-28'], IndexRange: ((0, 48415))
# Aircraft Included: ['PAL104', 'PAL105', 'PAL8455', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 10800000 - 10900000
# -------------------------------------------------------------------
# ID: [1634, 1644, 1646, 1654, 1662], Dates: ['2022-07-28', '2022-07-29', '2022-07-30'], IndexRange: ((0, 50587))
# Aircraft Included: ['PAL102', 'PAL8456', 'PAL103', 'PAL300', 'PAL301'], Registration Marking: ['RP7778']
# Index Counter: 10900000 - 11000000
# -------------------------------------------------------------------
# ID: [1662, 1673, 1752], Dates: ['2022-07-30', '2022-07-31', '2022-08-07'], IndexRange: ((0, 48703))
# Aircraft Included: ['PAL301', 'PAL117', 'PAL5102'], Registration Marking: ['RP7778']
# Index Counter: 11000000 - 11100000
# -------------------------------------------------------------------
# ID: [1752, 1755, 1762, 1767], Dates: ['2022-08-07', '2022-08-08', '2022-08-09'], IndexRange: ((0, 49575))
# Aircraft Included: ['PAL5102', 'PAL104', 'PAL5103', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 11100000 - 11200000
# -------------------------------------------------------------------
# ID: [1767, 1780, 1781], Dates: ['2022-08-09', '2022-08-10'], IndexRange: ((0, 50595))
# Aircraft Included: ['PAL105', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 11200000 - 11300000
# -------------------------------------------------------------------
# ID: [1781, 1788, 1797], Dates: ['2022-08-10', '2022-08-11', '2022-08-12'], IndexRange: ((0, 51591))
# Aircraft Included: ['PAL113', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 11300000 - 11400000
# -------------------------------------------------------------------
# ID: [1797, 1806, 1809], Dates: ['2022-08-12', '2022-08-13'], IndexRange: ((0, 48083))
# Aircraft Included: ['PAL105', 'PAL591', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 11400000 - 11500000
# -------------------------------------------------------------------
# ID: [1809, 1819, 1823, 1835], Dates: ['2022-08-13', '2022-08-14', '2022-08-15'], IndexRange: ((0, 47839))
# Aircraft Included: ['PAL104', 'PAL592', 'PAL105', 'PAL112'], Registration Marking: ['RP7778']
# Index Counter: 11500000 - 11600000
# -------------------------------------------------------------------
# ID: [1835, 1836, 1840], Dates: ['2022-08-15', '2022-08-16'], IndexRange: ((0, 50667))
# Aircraft Included: ['PAL112', 'PAL113', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 11600000 - 11700000
# -------------------------------------------------------------------
# ID: [1840, 1851, 1867], Dates: ['2022-08-16', '2022-08-17', '2022-08-18'], IndexRange: ((0, 49699))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 11700000 - 11800000
# -------------------------------------------------------------------
# ID: [1867, 1881, 1890, 1900], Dates: ['2022-08-18', '2022-08-19', '2022-08-20', '2022-08-21'], IndexRange: ((0, 46499))
# Aircraft Included: ['PAL116', 'PAL117', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 11800000 - 11900000
# -------------------------------------------------------------------
# ID: [1900, 1909, 1915], Dates: ['2022-08-21', '2022-08-22', '2022-08-23'], IndexRange: ((0, 47279))
# Aircraft Included: ['PAL105', 'PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 11900000 - 12000000
# -------------------------------------------------------------------
# ID: [1915, 1921, 1922], Dates: ['2022-08-23', '2022-08-24'], IndexRange: ((0, 50183))
# Aircraft Included: ['PAL117', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 12000000 - 12100000
# -------------------------------------------------------------------
# ID: [1922, 1925, 1940], Dates: ['2022-08-24', '2022-08-25', '2022-08-26'], IndexRange: ((0, 50603))
# Aircraft Included: ['PAL113', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 12100000 - 12200000
# -------------------------------------------------------------------
# ID: [1940, 1949, 1956, 1963, 1973], Dates: ['2022-08-26', '2022-08-27', '2022-08-28'], IndexRange: ((0, 49747))
# Aircraft Included: ['PAL103', 'PAL591', 'PAL116', 'PAL592', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 12200000 - 12300000
# -------------------------------------------------------------------
# ID: [1973, 1986], Dates: ['2022-08-28', '2022-08-29'], IndexRange: ((0, 55039))
# Aircraft Included: ['PAL117', 'PAL126'], Registration Marking: ['RP7778']
# Index Counter: 12300000 - 12400000
# -------------------------------------------------------------------
# ID: [1986, 1996, 1997, 2005], Dates: ['2022-08-29', '2022-08-30', '2022-08-31'], IndexRange: ((0, 57519))
# Aircraft Included: ['PAL126', 'PAL127', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 12400000 - 12500000
# -------------------------------------------------------------------
# ID: [2005, 2017, 2025], Dates: ['2022-08-31', '2022-09-01', '2022-09-02'], IndexRange: ((0, 45587))
# Aircraft Included: ['PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 12500000 - 12600000
# -------------------------------------------------------------------
# ID: [2025, 2030, 2031, 2040, 2043, 2046], Dates: ['2022-09-02', '2022-09-03', '2022-09-04'], IndexRange: ((0, 48411))
# Aircraft Included: ['PAL116', 'PAL730', 'PAL731', 'PAL117', 'PAL382', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 12600000 - 12700000
# -------------------------------------------------------------------
# ID: [2046, 2055, 2058, 2070], Dates: ['2022-09-04', '2022-09-05', '2022-09-06'], IndexRange: ((0, 50419))
# Aircraft Included: ['PAL102', 'PAL383', 'PAL103', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 12700000 - 12800000
# -------------------------------------------------------------------
# ID: [2070, 2078, 2085, 2088], Dates: ['2022-09-06', '2022-09-07', '2022-09-08'], IndexRange: ((0, 48387))
# Aircraft Included: ['PAL104', 'PAL105', 'PAL8455', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 12800000 - 12900000
# -------------------------------------------------------------------
# ID: [2088, 2095, 2100, 2110], Dates: ['2022-09-08', '2022-09-09', '2022-09-10'], IndexRange: ((0, 46999))
# Aircraft Included: ['PAL116', 'PAL8456', 'PAL117', 'PAL5104'], Registration Marking: ['RP7778']
# Index Counter: 12900000 - 13000000
# -------------------------------------------------------------------
# ID: [2110, 2111, 2115], Dates: ['2022-09-10', '2022-09-11'], IndexRange: ((0, 50675))
# Aircraft Included: ['PAL5104', 'PAL5105', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 13000000 - 13100000
# -------------------------------------------------------------------
# ID: [2115, 2123, 2125, 2129], Dates: ['2022-09-11', '2022-09-12', '2022-09-13'], IndexRange: ((0, 46199))
# Aircraft Included: ['PAL116', 'PAL117', 'PAL453P'], Registration Marking: ['RP7778']
# Index Counter: 13100000 - 13200000
# -------------------------------------------------------------------
# ID: [2129, 2132, 2141, 2151], Dates: ['2022-09-13', '2022-09-14', '2022-09-15'], IndexRange: ((0, 47623))
# Aircraft Included: ['PAL116', 'PAL454P', 'PAL117', 'PAL5104'], Registration Marking: ['RP7778']
# Index Counter: 13200000 - 13300000
# -------------------------------------------------------------------
# ID: [2151, 2152, 2153], Dates: ['2022-09-15', '2022-09-16'], IndexRange: ((0, 49651))
# Aircraft Included: ['PAL5104', 'PAL5105', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 13300000 - 13400000
# -------------------------------------------------------------------
# ID: [2153, 2166, 2170, 2174], Dates: ['2022-09-16', '2022-09-17', '2022-09-18'], IndexRange: ((0, 50659))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL453P', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 13400000 - 13500000
# -------------------------------------------------------------------
# ID: [2174, 2177, 2182, 2186], Dates: ['2022-09-18', '2022-09-19', '2022-09-20'], IndexRange: ((0, 47767))
# Aircraft Included: ['PAL116', 'PAL454P', 'PAL117', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 13500000 - 13600000
# -------------------------------------------------------------------
# ID: [2186, 2194, 2201, 2205], Dates: ['2022-09-20', '2022-09-21', '2022-09-22'], IndexRange: ((0, 47179))
# Aircraft Included: ['PAL104', 'PAL105', 'PAL8455', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 13600000 - 13700000
# -------------------------------------------------------------------
# ID: [2205, 2210, 2214, 2217, 2220], Dates: ['2022-09-22', '2022-09-23', '2022-09-24'], IndexRange: ((0, 47531))
# Aircraft Included: ['PAL116', 'PAL8456', 'PAL117', 'PAL591'], Registration Marking: ['RP7778']
# Index Counter: 13700000 - 13800000
# -------------------------------------------------------------------
# ID: [2220, 2227, 2233, 2244], Dates: ['2022-09-24', '2022-09-25', '2022-09-26'], IndexRange: ((0, 47531))
# Aircraft Included: ['PAL116', 'PAL592', 'PAL117', 'PAL5104'], Registration Marking: ['RP7778']
# Index Counter: 13800000 - 13900000
# -------------------------------------------------------------------
# ID: [2244, 2245, 2246], Dates: ['2022-09-26', '2022-09-27'], IndexRange: ((0, 52299))
# Aircraft Included: ['PAL5104', 'PAL5105', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 13900000 - 14000000
# -------------------------------------------------------------------
# ID: [2246, 2254, 2259, 2264], Dates: ['2022-09-27', '2022-09-28', '2022-09-29'], IndexRange: ((0, 50063))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL8455', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 14000000 - 14100000
# -------------------------------------------------------------------
# ID: [2264, 2268, 2273, 2283], Dates: ['2022-09-29', '2022-09-30', '2022-10-01'], IndexRange: ((0, 48455))
# Aircraft Included: ['PAL116', 'PAL8456', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 14100000 - 14200000
# -------------------------------------------------------------------
# ID: [2283, 2291, 2295], Dates: ['2022-10-01', '2022-10-02', '2022-10-03'], IndexRange: ((0, 48779))
# Aircraft Included: ['PAL116', 'PAL117', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 14200000 - 14300000
# -------------------------------------------------------------------
# ID: [2295, 2303, 2314], Dates: ['2022-10-03', '2022-10-04', '2022-10-05'], IndexRange: ((0, 49171))
# Aircraft Included: ['PAL104', 'PAL105', 'PAL112'], Registration Marking: ['RP7778']
# Index Counter: 14300000 - 14400000
# -------------------------------------------------------------------
# ID: [2314, 2315, 2319], Dates: ['2022-10-05', '2022-10-06'], IndexRange: ((0, 50599))
# Aircraft Included: ['PAL112', 'PAL113', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 14400000 - 14500000
# -------------------------------------------------------------------
# ID: [2319, 2328, 2344], Dates: ['2022-10-06', '2022-10-07', '2022-10-08'], IndexRange: ((0, 50307))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL5104'], Registration Marking: ['RP7778']
# Index Counter: 14500000 - 14600000
# -------------------------------------------------------------------
# ID: [2344, 2345, 2352], Dates: ['2022-10-08', '2022-10-09'], IndexRange: ((0, 48059))
# Aircraft Included: ['PAL5104', 'PAL5105', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 14600000 - 14700000
# -------------------------------------------------------------------
# ID: [2352, 2363, 2527, 2533, 2534], Dates: ['2022-10-09', '2022-10-10', '2022-10-29', '2022-10-30'], IndexRange: ((0, 47495))
# Aircraft Included: ['PAL116', 'PAL117', 'PAL452P', 'PAL454P', 'PAL5102'], Registration Marking: ['RP7778']
# Index Counter: 14700000 - 14800000
# -------------------------------------------------------------------
# ID: [2534, 2535, 2545, 2548], Dates: ['2022-10-30', '2022-10-31', '2022-11-01'], IndexRange: ((0, 51455))
# Aircraft Included: ['PAL5102', 'PAL5103', 'PAL428', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 14800000 - 14900000
# -------------------------------------------------------------------
# ID: [2548, 2555, 2557], Dates: ['2022-11-01', '2022-11-02'], IndexRange: ((0, 48179))
# Aircraft Included: ['PAL102', 'PAL427', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 14900000 - 15000000
# -------------------------------------------------------------------
# ID: [2557, 2563, 2569, 2571, 2577], Dates: ['2022-11-02', '2022-11-03', '2022-11-04'], IndexRange: ((0, 52723))
# Aircraft Included: ['PAL103', 'PAL300', 'PAL116', 'PAL301', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 15000000 - 15100000
# -------------------------------------------------------------------
# ID: [2577, 2578, 2580, 2590], Dates: ['2022-11-04', '2022-11-05', '2022-11-06'], IndexRange: ((0, 46391))
# Aircraft Included: ['PAL117', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 15100000 - 15200000
# -------------------------------------------------------------------
# ID: [2590, 2598, 2599], Dates: ['2022-11-06', '2022-11-07'], IndexRange: ((0, 52187))
# Aircraft Included: ['PAL103', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 15200000 - 15300000
# -------------------------------------------------------------------
# ID: [2599, 2605, 2612], Dates: ['2022-11-07', '2022-11-08', '2022-11-09'], IndexRange: ((0, 53583))
# Aircraft Included: ['PAL113', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 15300000 - 15400000
# -------------------------------------------------------------------
# ID: [2612, 2618, 2627], Dates: ['2022-11-09', '2022-11-10', '2022-11-11'], IndexRange: ((0, 50955))
# Aircraft Included: ['PAL105', 'PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 15400000 - 15500000
# -------------------------------------------------------------------
# ID: [2627, 2631, 2633, 2634, 2639], Dates: ['2022-11-11', '2022-11-12', '2022-11-13'], IndexRange: ((0, 54847))
# Aircraft Included: ['PAL117', 'PAL116', 'PAL453P', 'PAL454P'], Registration Marking: ['RP7778']
# Index Counter: 15500000 - 15600000
# -------------------------------------------------------------------
# ID: [2639, 2644, 2645], Dates: ['2022-11-13', '2022-11-14'], IndexRange: ((0, 48727))
# Aircraft Included: ['PAL117', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 15600000 - 15700000
# -------------------------------------------------------------------
# ID: [2645, 2655, 2666, 2667], Dates: ['2022-11-14', '2022-11-15', '2022-11-16'], IndexRange: ((0, 56683))
# Aircraft Included: ['PAL113', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 15700000 - 15800000
# -------------------------------------------------------------------
# ID: [2667, 2675, 2676], Dates: ['2022-11-16', '2022-11-17'], IndexRange: ((0, 51539))
# Aircraft Included: ['PAL105', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 15800000 - 15900000
# -------------------------------------------------------------------
# ID: [2676, 2685, 2693], Dates: ['2022-11-17', '2022-11-18', '2022-11-19'], IndexRange: ((0, 55935))
# Aircraft Included: ['PAL113', 'PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 15900000 - 16000000
# -------------------------------------------------------------------
# ID: [2693, 2701, 2702], Dates: ['2022-11-19', '2022-11-20'], IndexRange: ((0, 48947))
# Aircraft Included: ['PAL117', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 16000000 - 16100000
# -------------------------------------------------------------------
# ID: [2702, 2707, 2716], Dates: ['2022-11-20', '2022-11-21', '2022-11-22'], IndexRange: ((0, 55019))
# Aircraft Included: ['PAL113', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 16100000 - 16200000
# -------------------------------------------------------------------
# ID: [2716, 2726, 2727], Dates: ['2022-11-22', '2022-11-23'], IndexRange: ((0, 52187))
# Aircraft Included: ['PAL105', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 16200000 - 16300000
# -------------------------------------------------------------------
# ID: [2727, 2743, 2744], Dates: ['2022-11-23', '2022-11-27'], IndexRange: ((0, 54571))
# Aircraft Included: ['PAL113', 'PAL112'], Registration Marking: ['RP7778']
# Index Counter: 16300000 - 16400000
# -------------------------------------------------------------------
# ID: [2744, 2749, 2760], Dates: ['2022-11-27', '2022-11-28', '2022-11-29'], IndexRange: ((0, 53539))
# Aircraft Included: ['PAL113', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 16400000 - 16500000
# -------------------------------------------------------------------
# ID: [2760, 2772, 2782], Dates: ['2022-11-29', '2022-11-30', '2022-12-01'], IndexRange: ((0, 51355))
# Aircraft Included: ['PAL103', 'PAL104', 'PAL105'], Registration Marking: ['RP7778']
# Index Counter: 16500000 - 16600000
# -------------------------------------------------------------------
# ID: [2782, 2795, 2797, 2798, 2804], Dates: ['2022-12-01', '2022-12-02', '2022-12-03'], IndexRange: ((0, 51627))
# Aircraft Included: ['PAL105', 'PAL116', 'PAL730', 'PAL731', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 16600000 - 16700000
# -------------------------------------------------------------------
# ID: [2804, 2809, 2816, 2820], Dates: ['2022-12-03', '2022-12-04'], IndexRange: ((0, 55631))
# Aircraft Included: ['PAL117', 'PAL453P', 'PAL118', 'PAL454P'], Registration Marking: ['RP7778']
# Index Counter: 16700000 - 16800000
# -------------------------------------------------------------------
# ID: [2820, 2827, 2835], Dates: ['2022-12-04', '2022-12-05', '2022-12-06'], IndexRange: ((0, 57999))
# Aircraft Included: ['PAL454P', 'PAL119', 'PAL112'], Registration Marking: ['RP7778']
# Index Counter: 16800000 - 16900000
# -------------------------------------------------------------------
# ID: [2835, 2836, 2841], Dates: ['2022-12-06', '2022-12-07'], IndexRange: ((0, 54303))
# Aircraft Included: ['PAL112', 'PAL113', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 16900000 - 17000000
# -------------------------------------------------------------------
# ID: [2841, 2850, 2866, 2877], Dates: ['2022-12-07', '2022-12-08', '2022-12-09', '2022-12-10'], IndexRange: ((0, 51803))
# Aircraft Included: ['PAL104', 'PAL105', 'PAL116', 'PAL117'], Registration Marking: ['RP7778']
# Index Counter: 17000000 - 17100000
# -------------------------------------------------------------------
# ID: [2877, 2890], Dates: ['2022-12-10', '2022-12-11'], IndexRange: ((0, 51339))
# Aircraft Included: ['PAL117', 'PAL118'], Registration Marking: ['RP7778']
# Index Counter: 17100000 - 17200000
# -------------------------------------------------------------------
# ID: [2890, 2898, 2899], Dates: ['2022-12-11', '2022-12-12', '2022-12-13'], IndexRange: ((0, 59779))
# Aircraft Included: ['PAL118', 'PAL119', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 17200000 - 17300000
# -------------------------------------------------------------------
# ID: [2899, 2908, 2909, 2911, 2925], Dates: ['2022-12-13', '2022-12-14', '2022-12-15'], IndexRange: ((0, 53483))
# Aircraft Included: ['PAL102', 'PAL421', 'PAL422', 'PAL103', 'PAL114'], Registration Marking: ['RP7778']
# Index Counter: 17300000 - 17400000
# -------------------------------------------------------------------
# ID: [2925, 2931, 2942], Dates: ['2022-12-15', '2022-12-16', '2022-12-17'], IndexRange: ((0, 45155))
# Aircraft Included: ['PAL114', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 17400000 - 17500000
# -------------------------------------------------------------------
# ID: [2942, 2955, 2956], Dates: ['2022-12-17', '2022-12-18'], IndexRange: ((0, 56019))
# Aircraft Included: ['PAL103', 'PAL112', 'PAL113'], Registration Marking: ['RP7778']
# Index Counter: 17500000 - 17600000
# -------------------------------------------------------------------
# ID: [2956, 2966, 2977], Dates: ['2022-12-18', '2022-12-19', '2022-12-20'], IndexRange: ((0, 55239))
# Aircraft Included: ['PAL113', 'PAL102', 'PAL103'], Registration Marking: ['RP7778']
# Index Counter: 17600000 - 17700000
# -------------------------------------------------------------------
# ID: [2977, 2984, 2992, 2995, 2998], Dates: ['2022-12-20', '2022-12-21', '2022-12-22'], IndexRange: ((0, 54335))
# Aircraft Included: ['PAL103', 'PAL300', 'PAL116', 'PAL301', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 17700000 - 17800000
# -------------------------------------------------------------------
# ID: [2998, 3011, 3030], Dates: ['2022-12-22', '2022-12-23', '2022-12-24'], IndexRange: ((0, 57127))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL116'], Registration Marking: ['RP7778']
# Index Counter: 17800000 - 17900000
# -------------------------------------------------------------------
# ID: [3030, 3032, 3033, 3042, 3050], Dates: ['2022-12-24', '2022-12-25', '2022-12-26'], IndexRange: ((0, 54487))
# Aircraft Included: ['PAL116', 'PAL382', 'PAL383', 'PAL117', 'PAL112'], Registration Marking: ['RP7778']
# Index Counter: 17900000 - 18000000
# -------------------------------------------------------------------
# ID: [3050, 3051, 3056], Dates: ['2022-12-26', '2022-12-27'], IndexRange: ((0, 54183))
# Aircraft Included: ['PAL112', 'PAL113', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 18000000 - 18100000
# -------------------------------------------------------------------
# ID: [3056, 3074, 3088], Dates: ['2022-12-27', '2022-12-28', '2022-12-29'], IndexRange: ((0, 53231))
# Aircraft Included: ['PAL102', 'PAL103', 'PAL104'], Registration Marking: ['RP7778']
# Index Counter: 18100000 - 18200000
# -------------------------------------------------------------------
# ID: [3088, 3099, 3100, 3106, 3121], Dates: ['2022-12-29', '2022-12-30', '2022-12-31'], IndexRange: ((0, 54331))
# Aircraft Included: ['PAL104', 'PAL421', 'PAL422', 'PAL105', 'PAL102'], Registration Marking: ['RP7778']
# Index Counter: 18200000 - 18300000
# -------------------------------------------------------------------
# ID: [3121, 3131, 3132], Dates: ['2022-12-31'], IndexRange: ((0, 41491))
# Aircraft Included: ['PAL102', 'PAL421', 'PAL422'], Registration Marking: ['RP7778']
# Index Counter: 18300000 - 18400000
# -------------------------------------------------------------------
# AN ERROR OCCURED: min() arg is an empty sequence
