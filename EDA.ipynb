# %%
import pandas as pd
df = pd.read_csv ('AOC_2022-01-01_20230214115334.csv')
num_samples, num_variables = df.shape
print('number of samples: ', num_samples)
print('number of variables: ', num_variables)
df[['FUEL_UPLIFT','FUEL_AFTER_UPLIFT', 'FUEL_AT_BLOCK_OFF']].head()
# Out:
# number of samples:  78327
# number of variables:  41
#    FUEL_UPLIFT  FUEL_AFTER_UPLIFT  FUEL_AT_BLOCK_OFF
# 0      6700.01            6700.01            6622.44
# 1      2699.78           10544.66           10432.62
# 2      4100.02           10396.79           10341.90
# 3          NaN                NaN            2965.00
# 4          NaN                NaN            3100.00

# %%
for col in df.columns:
    print(col)
# Out:
# AIRLINE_DESG
# AIRCRAFT_OWNER
# FLT_NO
# CALL_SIGN
# AIRCRAFT_REGISTRATION
# DEP_AIRPORTCOMM
# DEP_AIRPORTSCHED
# DEP_AIRPORTACTUAL
# DEP_DATECOMMERCIAL
# DEP_DATESCHED
# DEP_DATEACTUAL
# ARR_AIRPORTCOMM
# ARR_AIRPORTSCHED
# ARR_AIRPORTACTUAL
# ARR_DATECOMMERCIAL
# ARR_DATESCHED
# ARR_DATEACTUAL
# AVAILABLE_SEAT_COUNT
# BLOCK_OFFDATE
# FUEL_AT_BLOCK_OFF
# TOFF_DATE
# FUEL_AT_TOFF
# LANDING_DATE
# FUEL_AT_LANDING
# BLOCK_ONDATE
# FUEL_AT_BLOCK_ON
# BLOCK_TIME
# FLIGHT_TIME
# MACTOW
# FUEL_UPLIFT
# FUEL_AFTER_UPLIFT
# CANCELLED
# IATA_SERVICE_TYPE
# PAX_CAPACITY
# PAX
# INFANT
# PAXMASS
# FUEL_TYPE
# ZFW_ACTUAL
# DOW
# TOTAL_PAYLOAD

# %%
for col in df.columns:
    n = df[col].nunique()
    if n < 10: 
        print(col, n)
        print(df[col].unique())
    else:
        print(col, n)
        unique = df[col].unique()
        print(unique[:10])
# Out:
# AIRLINE_DESG 2
# ['PR' '2P']
# AIRCRAFT_OWNER 2
# ['PR' '2P']
# FLT_NO 1087
# ['PR1842' 'PR1141' '2P2129' '2P2361' '2P2236' 'PR0453' '2P2545' '2P2836'
#  '2P2982' '2P2905']
# CALL_SIGN 1087
# ['PR1842' 'PR1141' '2P2129' '2P2361' '2P2236' 'PR0453' '2P2545' '2P2836'
#  '2P2982' '2P2905']
# AIRCRAFT_REGISTRATION 74
# ['RP-C9902' 'RP-C9906' 'RP-C9927' 'RP-C5907' 'RP-C5910' 'RP-C8766'
#  'RP-C8398' 'RP-C5915' 'RP-C8397' 'RP-C5905']
# DEP_AIRPORTCOMM 106
# ['CEB' 'MNL' 'TAC' 'DPL' 'MPH' 'BXU' 'TPE' 'OZC' 'CGY' 'BCD']
# DEP_AIRPORTSCHED 106
# ['CEB' 'MNL' 'TAC' 'DPL' 'MPH' 'BXU' 'TPE' 'OZC' 'CGY' 'BCD']
# DEP_AIRPORTACTUAL 106
# ['CEB' 'MNL' 'TAC' 'DPL' 'MPH' 'BXU' 'TPE' 'OZC' 'CGY' 'BCD']
# DEP_DATECOMMERCIAL 48487
# ['2022-01-01 00.20' '2022-01-01 00.15' '2022-01-01 00.00'
#  '2022-01-01 00.30' '2022-01-01 00.40' '2021-12-31 23.30'
#  '2022-01-01 01.00' '2022-01-01 01.10' '2022-01-01 01.20'
#  '2022-01-01 01.15']
# DEP_DATESCHED 48487
# ['2022-01-01 00.20' '2022-01-01 00.15' '2022-01-01 00.00'
#  '2022-01-01 00.30' '2022-01-01 00.40' '2021-12-31 23.30'
#  '2022-01-01 01.00' '2022-01-01 01.10' '2022-01-01 01.20'
#  '2022-01-01 01.15']
# DEP_DATEACTUAL 71140
# ['2022-01-01 00.03' '2022-01-01 00.06' '2022-01-01 00.10'
#  '2022-01-01 00.20' '2022-01-01 00.23' '2022-01-01 00.27'
#  '2022-01-01 00.37' '2022-01-01 00.45' '2022-01-01 00.50'
#  '2022-01-01 00.52']
# ARR_AIRPORTCOMM 111
# ['MNL' 'ILO' 'BCD' 'BXU' 'TAC' 'GES' 'DGT' 'EUQ' 'LGP' 'TAG']
# ARR_AIRPORTSCHED 111
# ['MNL' 'ILO' 'BCD' 'BXU' 'TAC' 'GES' 'DGT' 'EUQ' 'LGP' 'TAG']
# ARR_AIRPORTACTUAL 111
# ['MNL' 'ILO' 'BCD' 'BXU' 'TAC' 'GES' 'DGT' 'EUQ' 'LGP' 'TAG']
# ARR_DATECOMMERCIAL 50883
# ['2022-01-01 01.45' '2022-01-01 01.30' '2022-01-01 01.15'
#  '2022-01-01 02.10' '2022-01-01 02.05' '2022-01-01 01.00'
#  '2022-01-01 02.20' '2022-01-01 02.40' '2022-01-01 02.45'
#  '2022-01-01 02.30']
# ARR_DATESCHED 50883
# ['2022-01-01 01.45' '2022-01-01 01.30' '2022-01-01 01.15'
#  '2022-01-01 02.10' '2022-01-01 02.05' '2022-01-01 01.00'
#  '2022-01-01 02.20' '2022-01-01 02.40' '2022-01-01 02.45'
#  '2022-01-01 02.30']
# ARR_DATEACTUAL 71701
# ['2022-01-01 01.20' '2022-01-01 01.11' '2022-01-01 01.27'
#  '2022-01-01 01.10' '2022-01-01 01.04' '2022-01-01 02.24'
#  '2022-01-01 02.00' '2022-01-01 02.11' '2022-01-01 02.03'
#  '2022-01-01 02.19']
# AVAILABLE_SEAT_COUNT 11
# ['J12W18Y169' 'W6Y80' 'J18W33Y312' 'W12Y168' 'J12Y144' 'J12Y156' 'Y76'
#  'J42Y328' 'J12Y183' 'J18W24Y267']
# BLOCK_OFFDATE 71140
# ['2022-01-01 00.03.00' '2022-01-01 00.06.00' '2022-01-01 00.10.00'
#  '2022-01-01 00.20.00' '2022-01-01 00.23.00' '2022-01-01 00.27.00'
#  '2022-01-01 00.37.00' '2022-01-01 00.45.00' '2022-01-01 00.50.00'
#  '2022-01-01 00.52.00']
# FUEL_AT_BLOCK_OFF 4805
# [ 6622.44 10432.62 10341.9   2965.    3100.   27034.08  7212.11  2700.
#   7348.19  3850.  ]
# TOFF_DATE 72337
# ['2022-01-01 00.17.00' '2022-01-01 00.18.00' '2022-01-01 00.24.00'
#  '2022-01-01 00.35.00' '2022-01-01 00.33.00' '2022-01-01 00.42.00'
#  '2022-01-01 00.51.00' '2022-01-01 00.54.00' '2022-01-01 01.03.00'
#  '2022-01-01 01.09.00']
# FUEL_AT_TOFF 13543
# [ 6351.4  10184.6  10043.        nan 26484.1   6985.32  7212.11 11335.5
#   7348.19 10976.93]
# LANDING_DATE 72482
# ['2022-01-01 01.16.00' '2022-01-01 01.08.00' '2022-01-01 01.20.00'
#  '2022-01-01 00.58.00' '2022-01-01 02.15.00' '2022-01-01 01.57.00'
#  '2022-01-01 02.07.00' '2022-01-01 01.59.00' '2022-01-01 02.13.00'
#  '2022-01-01 02.26.00']
# FUEL_AT_LANDING 8420
# [ 3900.89  7700.2   7760.5       nan 18187.2   4082.33  4445.2   8336.
#   4263.76  4354.48]
# BLOCK_ONDATE 71703
# ['2022-01-01 01.20.00' '2022-01-01 01.11.00' '2022-01-01 01.27.00'
#  '2022-01-01 01.10.00' '2022-01-01 01.04.00' '2022-01-01 02.24.00'
#  '2022-01-01 02.00.00' '2022-01-01 02.11.00' '2022-01-01 02.03.00'
#  '2022-01-01 02.19.00']
# FUEL_AT_BLOCK_ON 2502
# [ 3855.53  7665.7   2415.    2665.   17962.24  4036.97  1560.    4399.84
#   2695.    2705.  ]
# BLOCK_TIME 1006
# [ 77  65  50  41 117  83  86  73  87  78]
# FLIGHT_TIME 942
# [59 50 56 33 25 93 66 73 65 72]
# MACTOW 210
# [20.3 27.9 26.5 19.6 27.1 27.7 29.8 32.  24.  25.7]
# FUEL_UPLIFT 234
# [ 6700.01  2699.78  4100.02      nan 18399.97  3699.95  7399.91  5199.98
#   7599.94  3899.99]
# FUEL_AFTER_UPLIFT 22074
# [ 6700.01 10544.66 10396.79      nan 27305.35  7403.53  7399.91 11718.56
#   7599.94 11405.13]
# CANCELLED 1
# [0]
# IATA_SERVICE_TYPE 12
# ['J' 'H' 'C' 'P' 'Z' 'R' 'G' 'X' 'T' 'N']
# PAX_CAPACITY 11
# ['J12W18Y169' 'W6Y80' 'J18W33Y312' 'W12Y168' 'J12Y144' 'J12Y156' 'Y76'
#  'J42Y328' 'J12Y183' 'J18W24Y267']
# PAX 372
# [ 39. 129.  54.  26.  28. 195. 149.  23. 131.   9.]
# INFANT 17
# [ 0.  2.  1.  4.  3. nan  5.  6.  7.  8.]
# PAXMASS 371
# [ 3900. 12900.  5400.  2600.  2800. 19500. 14900.  2300. 13100.   900.]
# FUEL_TYPE 2
# ['JET-A1' 'JET-A']
# ZFW_ACTUAL 34297
# [ 52142.  58145.  53546.  19967.  20119. 137434.  55725.  19699.  52556.
#   18563.]
# DOW 7288
# [ 48777.  48571.  48716.  18102.  18033. 122440.  42868.  17970.  42697.
#   17868.]
# TOTAL_PAYLOAD 25445
# [ 3365.  9574.  4830.  1865.  2086. 14994. 12857.  1729.  9859.   695.]

# %%
df
# Out:
#       AIRLINE_DESG AIRCRAFT_OWNER  FLT_NO CALL_SIGN AIRCRAFT_REGISTRATION  \
# 0               PR             PR  PR1842    PR1842              RP-C9902
# 1               PR             PR  PR1141    PR1141              RP-C9906
# 2               2P             2P  2P2129    2P2129              RP-C9927
# 3               2P             2P  2P2361    2P2361              RP-C5907
# 4               2P             2P  2P2236    2P2236              RP-C5910
# ...            ...            ...     ...       ...                   ...
# 78322           2P             2P  2P2962    2P2962              RP-C5901
# 78323           PR             PR  PR0525    PR0525              RP-C9915
# 78324           PR             PR  PR0300    PR0300              RP-C9917
# 78325           PR             PR  PR0434    PR0434              RP-C9902
# 78326           2P             2P  2P2933    2P2933              RP-C5910
#
#       DEP_AIRPORTCOMM DEP_AIRPORTSCHED DEP_AIRPORTACTUAL DEP_DATECOMMERCIAL  \
# 0                 CEB              CEB               CEB   2022-01-01 00.20
# 1                 MNL              MNL               MNL   2022-01-01 00.15
# 2                 MNL              MNL               MNL   2022-01-01 00.00
# 3                 CEB              CEB               CEB   2022-01-01 00.20
# 4                 CEB              CEB               CEB   2022-01-01 00.30
# ...               ...              ...               ...                ...
# 78322             USU              USU               USU   2022-12-31 23.40
# 78323             MNL              MNL               MNL   2022-12-31 22.55
# 78324             MNL              MNL               MNL   2022-12-31 23.50
# 78325             CEB              CEB               CEB   2022-12-31 23.50
# 78326             BSO              BSO               BSO   2023-01-01 00.20
#
#           DEP_DATESCHED  ... CANCELLED IATA_SERVICE_TYPE PAX_CAPACITY    PAX  \
# 0      2022-01-01 00.20  ...         0                 J   J12W18Y169   39.0
# 1      2022-01-01 00.15  ...         0                 J   J12W18Y169  129.0
# 2      2022-01-01 00.00  ...         0                 J   J12W18Y169   54.0
# 3      2022-01-01 00.20  ...         0                 J        W6Y80   26.0
# 4      2022-01-01 00.30  ...         0                 J        W6Y80   28.0
# ...                 ...  ...       ...               ...          ...    ...
# 78322  2022-12-31 23.40  ...         0                 J        W6Y80   45.0
# 78323  2022-12-31 22.55  ...         0                 J   J12W18Y169   95.0
# 78324  2022-12-31 23.50  ...         0                 J   J12W18Y169  116.0
# 78325  2022-12-31 23.50  ...         0                 J   J12W18Y169  104.0
# 78326  2023-01-01 00.20  ...         0                 J        W6Y80   53.0
#
#       INFANT  PAXMASS FUEL_TYPE ZFW_ACTUAL      DOW  TOTAL_PAYLOAD
# 0        0.0   3900.0    JET-A1    52142.0  48777.0         3365.0
# 1        2.0  12900.0    JET-A1    58145.0  48571.0         9574.0
# 2        1.0   5400.0    JET-A1    53546.0  48716.0         4830.0
# 3        0.0   2600.0    JET-A1    19967.0  18102.0         1865.0
# 4        2.0   2800.0    JET-A1    20119.0  18033.0         2086.0
# ...      ...      ...       ...        ...      ...            ...
# 78322    0.0   4500.0    JET-A1    21700.0  17897.0         3803.0
# 78323    0.0   9500.0    JET-A1    59100.0  49275.0         9825.0
# 78324    0.0  11600.0    JET-A1    60842.0  48869.0        11973.0
# 78325    0.0  10400.0    JET-A1    57277.0  49357.0         7920.0
# 78326    0.0   5300.0    JET-A1    22005.0  18113.0         3892.0
#
# [78327 rows x 41 columns]
